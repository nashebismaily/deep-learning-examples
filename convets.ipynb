# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# This classification assignment will use the CIFAR 10 library which is part of Keras. https://www.cs.toronto.edu/~kriz/cifar.html CIFAR 10 is a collection of 50,000 training and 10,000 test images of 10 differnt classes of objects.  Using convolutional neural networks (convets, or CNN) to get the model accuracy above 80%

# %%
# Load the libraries
# %tensorflow_version 2.x
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import backend, models, layers, regularizers
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load the CIFAR 10 library from Keras
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# %%
# View a few of the images
for i in range(0, 9):
    plt.subplot(3, 3, + 1 + i)
    plt.imshow(train_images[i])
plt.show()

# %%
train_images.shape,train_labels.shape,test_images.shape,test_labels.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
# Prepare the train and test images for a CNN
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')
train_images /= train_images.max()
test_images /= test_images.max()
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Split the data into a train and validation block
x_train, x_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.25, random_state=42)

# %%
x_train.shape,x_val.shape,y_train.shape,y_val.shape
# Out:
# ((37500, 32, 32, 3), (12500, 32, 32, 3), (37500, 10), (12500, 10))

# %%
classes = np.unique(train_labels)
nClasses = len(classes)
nRows,nCols,nDims = train_images.shape[1:]
train_data = train_images.reshape(train_images.shape[0], nRows, nCols, nDims)
test_data = test_images.reshape(test_images.shape[0], nRows, nCols, nDims)
input_shape = (nRows, nCols, nDims)
print(input_shape)
# Out:
# (32, 32, 3)

# %% [markdown]
# ### Review literature for CNN architectures and build at least 3 different architectures with varying depths, kernels, and normalization functions.  Be sure to split your data into a validation block and monitor loss and accuracy with graphs.  Build, compile, monitor, validate, and test each CNN architecture in one cell.  Try to get one of your CNN architectures to have a test accauracy above 80%.  You may use TensorBoard if you want.
#
# #### Here are some links to get you started on reviewing CNN architectures.
# #### https://www.kaggle.com/cdeotte/how-to-choose-cnn-architecture-mnist
# #### https://medium.com/datadriveninvestor/five-powerful-cnn-architectures-b939c9ddd57b

# %%
# VGG
backend.clear_session()
weight_decay=1e-4
model = models.Sequential()
model.add(layers.Conv2D(64, (3, 3), padding='same', input_shape=(32, 32, 3),kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10))
model.add(layers.Activation('softmax'))

model.summary()

model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

history = model.fit(x_train, y_train, 
          epochs = 50, 
          batch_size = 256,  
          validation_data=(x_val, y_val),
          verbose = 1,
          callbacks=[EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights = True)])

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss_values, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc_values, 'bo', label = 'Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_10 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_14 (Activation)   (None, 10)                0
# =================================================================
# Total params: 15,001,418
# Trainable params: 14,991,946
# Non-trainable params: 9,472
# _________________________________________________________________
# Epoch 1/50
#   2/147 [..............................] - ETA: 8s - loss: 4.0943 - accuracy: 0.0977WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0442s vs `on_train_batch_end` time: 0.0667s). Check your callbacks.
# 147/147 [==============================] - 20s 138ms/step - loss: 2.8686 - accuracy: 0.1954 - val_loss: 7.5440 - val_accuracy: 0.0988
# Epoch 2/50
# 147/147 [==============================] - 19s 128ms/step - loss: 2.2888 - accuracy: 0.3356 - val_loss: 3.6431 - val_accuracy: 0.1062
# Epoch 3/50
# 147/147 [==============================] - 18s 125ms/step - loss: 2.0131 - accuracy: 0.4394 - val_loss: 23.4121 - val_accuracy: 0.1063
# Epoch 4/50
# 147/147 [==============================] - 18s 124ms/step - loss: 1.7825 - accuracy: 0.5351 - val_loss: 2.3846 - val_accuracy: 0.3849
# Epoch 5/50
# 147/147 [==============================] - 18s 124ms/step - loss: 1.6276 - accuracy: 0.5874 - val_loss: 2.5419 - val_accuracy: 0.3687
# Epoch 6/50
# 147/147 [==============================] - 18s 125ms/step - loss: 1.5149 - accuracy: 0.6303 - val_loss: 1.4896 - val_accuracy: 0.6453
# Epoch 7/50
# 147/147 [==============================] - 18s 125ms/step - loss: 1.3633 - accuracy: 0.6785 - val_loss: 1.3949 - val_accuracy: 0.6796
# Epoch 8/50
# 147/147 [==============================] - 18s 124ms/step - loss: 1.2647 - accuracy: 0.7116 - val_loss: 1.3921 - val_accuracy: 0.6806
# Epoch 9/50
# 147/147 [==============================] - 18s 124ms/step - loss: 1.1929 - accuracy: 0.7363 - val_loss: 1.3467 - val_accuracy: 0.7285
# Epoch 10/50
# 147/147 [==============================] - 18s 124ms/step - loss: 1.1104 - accuracy: 0.7627 - val_loss: 1.2134 - val_accuracy: 0.7426
# Epoch 11/50
# 147/147 [==============================] - 18s 125ms/step - loss: 1.0466 - accuracy: 0.7813 - val_loss: 1.2920 - val_accuracy: 0.7512
# Epoch 12/50
# 147/147 [==============================] - 18s 125ms/step - loss: 0.9968 - accuracy: 0.7984 - val_loss: 1.2558 - val_accuracy: 0.7558
# Epoch 13/50
# 147/147 [==============================] - 18s 125ms/step - loss: 0.9564 - accuracy: 0.8098 - val_loss: 1.0962 - val_accuracy: 0.7756
# Epoch 14/50
# 147/147 [==============================] - 18s 125ms/step - loss: 0.9204 - accuracy: 0.8195 - val_loss: 1.0658 - val_accuracy: 0.7822
# Epoch 15/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.8884 - accuracy: 0.8293 - val_loss: 1.0515 - val_accuracy: 0.7886
# Epoch 16/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.8686 - accuracy: 0.8373 - val_loss: 1.0383 - val_accuracy: 0.8036
# Epoch 17/50
# 147/147 [==============================] - 18s 125ms/step - loss: 0.8306 - accuracy: 0.8507 - val_loss: 0.9438 - val_accuracy: 0.8225
# Epoch 18/50
# 147/147 [==============================] - 18s 125ms/step - loss: 0.8141 - accuracy: 0.8571 - val_loss: 1.0910 - val_accuracy: 0.7888
# Epoch 19/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.8055 - accuracy: 0.8637 - val_loss: 1.0618 - val_accuracy: 0.7910
# Epoch 20/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.7942 - accuracy: 0.8677 - val_loss: 1.0012 - val_accuracy: 0.8162
# Epoch 21/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.7772 - accuracy: 0.8767 - val_loss: 1.0123 - val_accuracy: 0.8131
# Epoch 22/50
# 147/147 [==============================] - 18s 124ms/step - loss: 0.7841 - accuracy: 0.8799 - val_loss: 1.0340 - val_accuracy: 0.8201
# 313/313 [==============================] - 3s 11ms/step - loss: 0.9540 - accuracy: 0.8223
# test_acc: 0.8223000168800354

# %%
backend.clear_session()
model = models.Sequential()
model.add(layers.Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.Dense(500, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

history = model.fit(x_train, y_train, 
          epochs = 50, 
          batch_size = 256,  
          validation_data=(x_val, y_val),
          verbose = 1,
          callbacks=[EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights = True)])

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss_values, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc_values, 'bo', label = 'Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               512500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 147/147 [==============================] - 2s 10ms/step - loss: 1.8248 - accuracy: 0.3347 - val_loss: 1.4685 - val_accuracy: 0.4749
# Epoch 2/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.4775 - accuracy: 0.4658 - val_loss: 1.3523 - val_accuracy: 0.5178
# Epoch 3/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.3597 - accuracy: 0.5103 - val_loss: 1.2809 - val_accuracy: 0.5447
# Epoch 4/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.2870 - accuracy: 0.5397 - val_loss: 1.1747 - val_accuracy: 0.5853
# Epoch 5/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.2357 - accuracy: 0.5551 - val_loss: 1.1716 - val_accuracy: 0.5843
# Epoch 6/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.1799 - accuracy: 0.5789 - val_loss: 1.1085 - val_accuracy: 0.6095
# Epoch 7/50
# 147/147 [==============================] - 1s 9ms/step - loss: 1.1495 - accuracy: 0.5913 - val_loss: 1.0706 - val_accuracy: 0.6226
# Epoch 8/50
# 147/147 [==============================] - 1s 9ms/step - loss: 1.1093 - accuracy: 0.6071 - val_loss: 1.0650 - val_accuracy: 0.6250
# Epoch 9/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.0795 - accuracy: 0.6155 - val_loss: 1.0318 - val_accuracy: 0.6390
# Epoch 10/50
# 147/147 [==============================] - 1s 9ms/step - loss: 1.0426 - accuracy: 0.6303 - val_loss: 0.9831 - val_accuracy: 0.6559
# Epoch 11/50
# 147/147 [==============================] - 1s 8ms/step - loss: 1.0129 - accuracy: 0.6424 - val_loss: 0.9757 - val_accuracy: 0.6586
# Epoch 12/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.9850 - accuracy: 0.6527 - val_loss: 0.9482 - val_accuracy: 0.6666
# Epoch 13/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.9740 - accuracy: 0.6556 - val_loss: 0.9395 - val_accuracy: 0.6742
# Epoch 14/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.9394 - accuracy: 0.6683 - val_loss: 0.9133 - val_accuracy: 0.6836
# Epoch 15/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.9270 - accuracy: 0.6691 - val_loss: 0.9000 - val_accuracy: 0.6870
# Epoch 16/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.8976 - accuracy: 0.6835 - val_loss: 0.9018 - val_accuracy: 0.6840
# Epoch 17/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.8738 - accuracy: 0.6917 - val_loss: 0.8840 - val_accuracy: 0.6886
# Epoch 18/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.8568 - accuracy: 0.6941 - val_loss: 0.8866 - val_accuracy: 0.6906
# Epoch 19/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.8456 - accuracy: 0.7001 - val_loss: 0.8537 - val_accuracy: 0.7022
# Epoch 20/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.8257 - accuracy: 0.7086 - val_loss: 0.8544 - val_accuracy: 0.7021
# Epoch 21/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.8113 - accuracy: 0.7123 - val_loss: 0.8563 - val_accuracy: 0.7058
# Epoch 22/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.7946 - accuracy: 0.7206 - val_loss: 0.8387 - val_accuracy: 0.7105
# Epoch 23/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.7709 - accuracy: 0.7277 - val_loss: 0.8368 - val_accuracy: 0.7087
# Epoch 24/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.7503 - accuracy: 0.7330 - val_loss: 0.8395 - val_accuracy: 0.7070
# Epoch 25/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.7443 - accuracy: 0.7378 - val_loss: 0.8079 - val_accuracy: 0.7158
# Epoch 26/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.7269 - accuracy: 0.7435 - val_loss: 0.8048 - val_accuracy: 0.7201
# Epoch 27/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.7105 - accuracy: 0.7495 - val_loss: 0.7972 - val_accuracy: 0.7250
# Epoch 28/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.6976 - accuracy: 0.7537 - val_loss: 0.8016 - val_accuracy: 0.7230
# Epoch 29/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.6824 - accuracy: 0.7576 - val_loss: 0.7850 - val_accuracy: 0.7271
# Epoch 30/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.6711 - accuracy: 0.7630 - val_loss: 0.7883 - val_accuracy: 0.7283
# Epoch 31/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.6520 - accuracy: 0.7678 - val_loss: 0.7849 - val_accuracy: 0.7287
# Epoch 32/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.6408 - accuracy: 0.7746 - val_loss: 0.7794 - val_accuracy: 0.7315
# Epoch 33/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.6300 - accuracy: 0.7758 - val_loss: 0.7786 - val_accuracy: 0.7314
# Epoch 34/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.6161 - accuracy: 0.7805 - val_loss: 0.7672 - val_accuracy: 0.7339
# Epoch 35/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.6143 - accuracy: 0.7807 - val_loss: 0.7887 - val_accuracy: 0.7318
# Epoch 36/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5944 - accuracy: 0.7881 - val_loss: 0.7663 - val_accuracy: 0.7367
# Epoch 37/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5826 - accuracy: 0.7939 - val_loss: 0.7699 - val_accuracy: 0.7333
# Epoch 38/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5796 - accuracy: 0.7950 - val_loss: 0.7848 - val_accuracy: 0.7285
# Epoch 39/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5671 - accuracy: 0.7979 - val_loss: 0.7760 - val_accuracy: 0.7338
# Epoch 40/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5597 - accuracy: 0.7996 - val_loss: 0.7631 - val_accuracy: 0.7408
# Epoch 41/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5460 - accuracy: 0.8064 - val_loss: 0.7726 - val_accuracy: 0.7377
# Epoch 42/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.5322 - accuracy: 0.8117 - val_loss: 0.7688 - val_accuracy: 0.7390
# Epoch 43/50
# 147/147 [==============================] - 1s 8ms/step - loss: 0.5216 - accuracy: 0.8130 - val_loss: 0.7722 - val_accuracy: 0.7404
# Epoch 44/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5213 - accuracy: 0.8135 - val_loss: 0.7757 - val_accuracy: 0.7371
# Epoch 45/50
# 147/147 [==============================] - 1s 9ms/step - loss: 0.5087 - accuracy: 0.8193 - val_loss: 0.7861 - val_accuracy: 0.7358
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7706 - accuracy: 0.7326
# test_acc: 0.7325999736785889

# %%
backend.clear_session()
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

history = model.fit(x_train, y_train, 
          epochs = 50, 
          batch_size = 256,  
          validation_data=(x_val, y_val),
          verbose = 1,
          callbacks=[EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights = True)])

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss_values, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc_values, 'bo', label = 'Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 64)          36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 276,138
# Trainable params: 276,138
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 147/147 [==============================] - 3s 24ms/step - loss: 1.9413 - accuracy: 0.2518 - val_loss: 1.6470 - val_accuracy: 0.3849
# Epoch 2/50
# 147/147 [==============================] - 3s 20ms/step - loss: 1.5451 - accuracy: 0.4236 - val_loss: 1.3620 - val_accuracy: 0.4933
# Epoch 3/50
# 147/147 [==============================] - 3s 20ms/step - loss: 1.3567 - accuracy: 0.5011 - val_loss: 1.1993 - val_accuracy: 0.5602
# Epoch 4/50
# 147/147 [==============================] - 3s 20ms/step - loss: 1.2364 - accuracy: 0.5544 - val_loss: 1.0933 - val_accuracy: 0.6034
# Epoch 5/50
# 147/147 [==============================] - 3s 20ms/step - loss: 1.1556 - accuracy: 0.5837 - val_loss: 1.0386 - val_accuracy: 0.6228
# Epoch 6/50
# 147/147 [==============================] - 3s 21ms/step - loss: 1.0648 - accuracy: 0.6195 - val_loss: 0.9674 - val_accuracy: 0.6570
# Epoch 7/50
# 147/147 [==============================] - 3s 21ms/step - loss: 1.0073 - accuracy: 0.6439 - val_loss: 0.9027 - val_accuracy: 0.6733
# Epoch 8/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.9545 - accuracy: 0.6622 - val_loss: 0.8859 - val_accuracy: 0.6830
# Epoch 9/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.9150 - accuracy: 0.6764 - val_loss: 0.8409 - val_accuracy: 0.6982
# Epoch 10/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.8650 - accuracy: 0.6970 - val_loss: 0.8134 - val_accuracy: 0.7116
# Epoch 11/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.8327 - accuracy: 0.7086 - val_loss: 0.7810 - val_accuracy: 0.7262
# Epoch 12/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.7961 - accuracy: 0.7187 - val_loss: 0.7281 - val_accuracy: 0.7444
# Epoch 13/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.7595 - accuracy: 0.7339 - val_loss: 0.7193 - val_accuracy: 0.7514
# Epoch 14/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.7367 - accuracy: 0.7430 - val_loss: 0.7217 - val_accuracy: 0.7497
# Epoch 15/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.7091 - accuracy: 0.7509 - val_loss: 0.6857 - val_accuracy: 0.7602
# Epoch 16/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.6948 - accuracy: 0.7582 - val_loss: 0.6850 - val_accuracy: 0.7587
# Epoch 17/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.6795 - accuracy: 0.7627 - val_loss: 0.6764 - val_accuracy: 0.7594
# Epoch 18/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.6550 - accuracy: 0.7695 - val_loss: 0.6872 - val_accuracy: 0.7624
# Epoch 19/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.6558 - accuracy: 0.7717 - val_loss: 0.6547 - val_accuracy: 0.7713
# Epoch 20/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.6266 - accuracy: 0.7791 - val_loss: 0.6706 - val_accuracy: 0.7658
# Epoch 21/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.6076 - accuracy: 0.7858 - val_loss: 0.6385 - val_accuracy: 0.7792
# Epoch 22/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.5894 - accuracy: 0.7929 - val_loss: 0.6099 - val_accuracy: 0.7933
# Epoch 23/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.5906 - accuracy: 0.7939 - val_loss: 0.6426 - val_accuracy: 0.7823
# Epoch 24/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.5751 - accuracy: 0.7989 - val_loss: 0.6327 - val_accuracy: 0.7806
# Epoch 25/50
# 147/147 [==============================] - 3s 21ms/step - loss: 0.5586 - accuracy: 0.8040 - val_loss: 0.6297 - val_accuracy: 0.7878
# Epoch 26/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.5519 - accuracy: 0.8066 - val_loss: 0.6511 - val_accuracy: 0.7751
# Epoch 27/50
# 147/147 [==============================] - 3s 20ms/step - loss: 0.5397 - accuracy: 0.8077 - val_loss: 0.6067 - val_accuracy: 0.7906
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6257 - accuracy: 0.7872
# test_acc: 0.7871999740600586

# %%
backend.clear_session()
weight_decay=1e-4
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=(32, 32, 3)))
model.add(layers.Activation('elu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('elu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('elu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('elu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('elu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.Activation('elu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Dropout(0.4))
 
model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

history = model.fit(x_train, y_train, 
          epochs = 50, 
          batch_size = 256,  
          validation_data=(x_val, y_val),
          verbose = 1,
          callbacks=[EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights = True)])

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss_values, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc_values, 'bo', label = 'Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/50
# 147/147 [==============================] - 5s 37ms/step - loss: 1.9942 - accuracy: 0.4010 - val_loss: 3.9624 - val_accuracy: 0.1172
# Epoch 2/50
# 147/147 [==============================] - 5s 33ms/step - loss: 1.3658 - accuracy: 0.5558 - val_loss: 2.2523 - val_accuracy: 0.3102
# Epoch 3/50
# 147/147 [==============================] - 5s 33ms/step - loss: 1.1089 - accuracy: 0.6362 - val_loss: 1.2944 - val_accuracy: 0.5580
# Epoch 4/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.9671 - accuracy: 0.6797 - val_loss: 0.9560 - val_accuracy: 0.6832
# Epoch 5/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.8822 - accuracy: 0.7082 - val_loss: 0.8298 - val_accuracy: 0.7334
# Epoch 6/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.8095 - accuracy: 0.7316 - val_loss: 0.8433 - val_accuracy: 0.7258
# Epoch 7/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.7602 - accuracy: 0.7479 - val_loss: 0.7634 - val_accuracy: 0.7594
# Epoch 8/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.7097 - accuracy: 0.7691 - val_loss: 0.7414 - val_accuracy: 0.7650
# Epoch 9/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.6741 - accuracy: 0.7800 - val_loss: 0.8045 - val_accuracy: 0.7580
# Epoch 10/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.6445 - accuracy: 0.7899 - val_loss: 0.7610 - val_accuracy: 0.7690
# Epoch 11/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.6139 - accuracy: 0.8036 - val_loss: 0.7707 - val_accuracy: 0.7696
# Epoch 12/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.5816 - accuracy: 0.8158 - val_loss: 0.6748 - val_accuracy: 0.7993
# Epoch 13/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.5567 - accuracy: 0.8217 - val_loss: 0.6925 - val_accuracy: 0.7917
# Epoch 14/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.5338 - accuracy: 0.8318 - val_loss: 0.7029 - val_accuracy: 0.7928
# Epoch 15/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.5078 - accuracy: 0.8430 - val_loss: 0.6663 - val_accuracy: 0.8034
# Epoch 16/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.4978 - accuracy: 0.8458 - val_loss: 0.6662 - val_accuracy: 0.8005
# Epoch 17/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.4708 - accuracy: 0.8555 - val_loss: 0.7193 - val_accuracy: 0.7949
# Epoch 18/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.4555 - accuracy: 0.8621 - val_loss: 0.7311 - val_accuracy: 0.7920
# Epoch 19/50
# 147/147 [==============================] - 5s 34ms/step - loss: 0.4378 - accuracy: 0.8687 - val_loss: 0.6562 - val_accuracy: 0.8138
# Epoch 20/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.4205 - accuracy: 0.8760 - val_loss: 0.7599 - val_accuracy: 0.7966
# Epoch 21/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.4160 - accuracy: 0.8776 - val_loss: 0.7021 - val_accuracy: 0.8036
# Epoch 22/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.4021 - accuracy: 0.8834 - val_loss: 0.6349 - val_accuracy: 0.8281
# Epoch 23/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.3955 - accuracy: 0.8867 - val_loss: 0.7115 - val_accuracy: 0.8034
# Epoch 24/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.3881 - accuracy: 0.8899 - val_loss: 0.6687 - val_accuracy: 0.8279
# Epoch 25/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.3794 - accuracy: 0.8946 - val_loss: 0.6842 - val_accuracy: 0.8184
# Epoch 26/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.3674 - accuracy: 0.8986 - val_loss: 0.6802 - val_accuracy: 0.8278
# Epoch 27/50
# 147/147 [==============================] - 5s 33ms/step - loss: 0.3618 - accuracy: 0.8998 - val_loss: 0.7178 - val_accuracy: 0.8135
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6635 - accuracy: 0.8178
# test_acc: 0.817799985408783
